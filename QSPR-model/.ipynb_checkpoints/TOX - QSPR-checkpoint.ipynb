# %% [markdown]
# # TOX24 Challenge

# %% [markdown]
# https://ochem.eu/static/challenge.do

# %% [markdown]
# ### Goal
# Tox24 Challenge is designed to assess the progress in computational methods for predicting in vitro activity of compounds. The development of these methods has steadily gained momentum.

# %% [markdown]
# ### Data
# The chemicals and compounds being tested for activity against Transthyretin (TTR) within the “Toxicology in the 21st Century” (Tox21) initiative by the EPA will be used as the training and test sets for the Tox24 challenge. The initial dataset has been split into a training set (1012 compounds), a leaderboard set (200 compounds) and a blind set (300 compounds).

# %% [markdown]
# Refer `TOX - EDA.ipynb` for EDA

# %% [markdown]
# ### QSPR Models

# %%
#import
import numpy as np
import pandas as pd
from rdkit import Chem
import seaborn as sns
import matplotlib.pyplot as plt
from rdkit.Chem import Descriptors, rdMolDescriptors, AllChem, DataStructs

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.model_selection import cross_val_score, cross_val_predict, KFold
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## XGBOOST - Descriptors

# %%
def generate_2d_descriptors(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None
    return {desc_name: func(mol) for desc_name, func in Descriptors.descList}

# %%
def generate_3d_descriptors(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None 
    mol = Chem.AddHs(mol)  

    try:
        AllChem.EmbedMolecule(mol, AllChem.ETKDG())
        AllChem.UFFOptimizeMolecule(mol)

        descriptors_3d = {
            "radius_of_gyration": rdMolDescriptors.CalcRadiusOfGyration(mol),
            "asphericity": rdMolDescriptors.CalcAsphericity(mol),
            "spherocity_index": rdMolDescriptors.CalcSpherocityIndex(mol),
            "eccentricity": rdMolDescriptors.CalcEccentricity(mol),
            "NPR1": rdMolDescriptors.CalcNPR1(mol),
            "NPR2": rdMolDescriptors.CalcNPR2(mol),
            "PMI1": rdMolDescriptors.CalcPMI1(mol),
            "PMI2": rdMolDescriptors.CalcPMI2(mol),
            "PMI3": rdMolDescriptors.CalcPMI3(mol),
        }

        return descriptors_3d

    except:
        return None

# %%
datafile = pd.read_csv("tox24_challenge_train.csv")

# %%
smiles_list = datafile["SMILES"].to_list()
activity_values = datafile["activity"].to_list()

# %%
data = []
for smiles in smiles_list:
    descriptors_2d = generate_2d_descriptors(smiles)
    descriptors_3d = generate_3d_descriptors(smiles)

    if descriptors_2d and descriptors_3d:
        combined_descriptors = {**descriptors_2d, **descriptors_3d}
        combined_descriptors["SMILES"] = smiles
        data.append(combined_descriptors)
# Out:
# [01:33:39] UFFTYPER: Unrecognized atom type: Ca1+2 (0)
# [01:33:39] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [01:33:39] UFFTYPER: Unrecognized atom type: Ca1+2 (0)
# [01:33:39] UFFTYPER: Unrecognized atom type: Ca+2 (1)
# [01:33:43] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [01:33:43] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (1)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (2)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (3)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (4)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (5)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (6)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (7)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (8)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (9)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (10)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (11)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (12)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (13)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (14)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (15)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (16)
# [01:33:45] UFFTYPER: Unrecognized atom type: Co3+3 (17)
# [01:33:51] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [01:33:51] UFFTYPER: Unrecognized charge state for atom: 0
# [01:33:51] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [01:33:51] UFFTYPER: Unrecognized charge state for atom: 0
# [01:33:53] UFFTYPER: Unrecognized charge state for atom: 1
# [01:33:53] UFFTYPER: Unrecognized charge state for atom: 1
# [01:33:55] UFFTYPER: Unrecognized charge state for atom: 0
# [01:33:55] UFFTYPER: Unrecognized atom type: Dy3+3 (0)
# [01:33:55] UFFTYPER: Unrecognized charge state for atom: 3
# [01:33:55] UFFTYPER: Unrecognized atom type: Dy3+3 (3)
# [01:34:16] UFFTYPER: Unrecognized atom type: As1+3 (0)
# [01:34:16] UFFTYPER: Unrecognized atom type: In+3 (1)
# [01:34:16] UFFTYPER: Unrecognized atom type: As1+3 (0)
# [01:34:16] UFFTYPER: Unrecognized atom type: In+3 (1)
# [01:34:17] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [01:34:17] UFFTYPER: Unrecognized charge state for atom: 0
# [01:34:17] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [01:34:17] UFFTYPER: Unrecognized charge state for atom: 0
# [01:34:18] UFFTYPER: Unrecognized atom type: Mn2+2 (0)
# [01:34:18] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# [01:34:18] UFFTYPER: Unrecognized atom type: Mn2+2 (20)
# [01:34:18] UFFTYPER: Unrecognized atom type: Zn+2 (21)
# [01:34:18] UFFTYPER: Unrecognized atom type: Mn2+2 (0)
# [01:34:18] UFFTYPER: Unrecognized atom type: Mn2+2 (0)
# [01:34:24] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [01:34:24] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [01:34:34] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# [01:34:34] UFFTYPER: Unrecognized atom type: Zn+2 (0)

# %%
df = pd.DataFrame(data)

# %%
data = datafile.merge(df,on="SMILES").drop_duplicates()

# %%
data.columns
# Out:
# Index(['SMILES', 'activity', 'MaxAbsEStateIndex', 'MaxEStateIndex',
#        'MinAbsEStateIndex', 'MinEStateIndex', 'qed', 'SPS', 'MolWt',
#        'HeavyAtomMolWt',
#        ...
#        'fr_urea', 'radius_of_gyration', 'asphericity', 'spherocity_index',
#        'eccentricity', 'NPR1', 'NPR2', 'PMI1', 'PMI2', 'PMI3'],
#       dtype='object', length=221)

# %%
cor = abs(data.corr()["activity"])
# Out:
# C:\Users\shasa\AppData\Local\Temp\ipykernel_32044\3962194765.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor = abs(data.corr()["activity"])

# %%
plt.plot(abs(data.corr()["activity"]))
# Out:
# C:\Users\shasa\AppData\Local\Temp\ipykernel_32044\967887815.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.plot(abs(data.corr()["activity"]))

# %% [markdown]
# ### XGBOOST Regressor

# %%
final = data[cor[cor>0.2].index]
#final = data.copy()

# %%
#final["SMILES"] = data["SMILES"]

# %%
final.columns
# Out:
# Index(['activity', 'MinEStateIndex', 'MolWt', 'HeavyAtomMolWt', 'ExactMolWt',
#        'MinPartialCharge', 'MaxAbsPartialCharge', 'BCUT2D_LOGPHI',
#        'BCUT2D_MRHI', 'AvgIpc', 'BertzCT', 'Chi0', 'LabuteASA', 'SMR_VSA7',
#        'SMR_VSA9', 'SlogP_VSA10', 'SlogP_VSA11', 'SlogP_VSA6', 'EState_VSA10',
#        'VSA_EState1', 'VSA_EState6', 'FractionCSP3', 'HeavyAtomCount',
#        'NumAromaticCarbocycles', 'NumAromaticRings', 'MolLogP', 'fr_Ar_OH',
#        'fr_benzene', 'fr_phenol', 'fr_phenol_noOrthoHbond',
#        'radius_of_gyration'],
#       dtype='object')

# %%
final.shape
# Out:
# (1006, 31)

# %%
#final.drop('SMILES', axis=1,inplace=True)

# %%
scaler = MinMaxScaler() #scaling
final_scale = pd.DataFrame(scaler.fit_transform(final.drop('activity', axis=1)),columns=final.columns.to_list()[1:])

# %%
X = final_scale
y = final['activity']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# %%
cv = KFold(n_splits=5, shuffle=True, random_state=42)
y_pred_cv = cross_val_predict(model, X_train, y_train, cv=cv)
rmse = np.sqrt(mean_squared_error(y_train, y_pred_cv))
r2 = r2_score(y_train, y_pred_cv)

print(f'Cross-Validation RMSE: {rmse:.4f}')
print(f'Cross-Validation R²: {r2:.4f}')
# Out:
# Cross-Validation RMSE: 27.2010
# Cross-Validation R²: 0.4253

# %%
model.fit(X_train, y_train)

y_pred_test = model.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))
r2_test = r2_score(y_test, y_pred_test)

print(f'Test RMSE: {rmse_test:.4f}')
print(f'Test R²: {r2_test:.4f}')
# Out:
# Test RMSE: 28.2274
# Test R²: 0.4371

# %%
idx = model.feature_importances_.argsort()

# %%
plt.barh(X_train.columns[idx][20:30],model.feature_importances_[idx][20:30])
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## NN - Fingerprint

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
class NNRegressor(nn.Module):
    def __init__(self, input_dim, hidden_dim1, hidden_dim2, hidden_dim3,hidden_dim4, dropout_rate):
        super(NNRegressor, self).__init__()
        
        self.fc1 = nn.Linear(input_dim, hidden_dim1)
        self.fc2 = nn.Linear(hidden_dim1, hidden_dim2)
        self.fc3 = nn.Linear(hidden_dim2, hidden_dim3) 
        self.fc4 = nn.Linear(hidden_dim3, hidden_dim4) 
        self.fc5 = nn.Linear(hidden_dim4, 1)
        
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        
        x = self.fc2(x)
        x = self.relu(x)
        x = self.dropout(x)

        x = self.fc3(x)
        x = self.relu(x)
        x = self.dropout(x)

        x = self.fc4(x)
        x = self.relu(x)
        x = self.dropout(x)

        x = self.fc5(x)
        return x 

class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()
        self.mse = nn.MSELoss()

    def forward(self, y_pred, y_true):
        return torch.sqrt(self.mse(y_pred, y_true))

class NNDataset(Dataset):
    def __init__(self, df, label_column):
        self.embeddings = torch.tensor(df.drop(columns=[label_column]).values, dtype=torch.float32)
        self.labels = torch.tensor(df[label_column].values, dtype=torch.float32).unsqueeze(1) 

    def __len__(self):
        return len(self.embeddings)

    def __getitem__(self, idx):
        return self.embeddings[idx], self.labels[idx]

# %%
def train_model(model, data_loader, optimizer, criterion, epochs):
    model.train()
    for epoch in range(epochs):
        epoch_loss = 0
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
        
        print(f"Epoch [{epoch+1}/{epochs}], RMSE Loss: {epoch_loss / len(data_loader):.4f}")

# %%
def evaluate_model(model, data_loader, criterion):
    model.eval()
    all_preds = []
    all_labels = []

    total_loss = 0
    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            all_preds.extend(outputs.cpu().numpy().flatten())
            all_labels.extend(labels.cpu().numpy().flatten())

    rmse = np.sqrt(mean_squared_error(all_labels, all_preds))
    print(f"Test RMSE Loss: {rmse:.4f}")

    r2_test = r2_score(all_labels, all_preds)
    print(f'Test R²: {r2_test:.4f}')


    plt.figure(figsize=(6, 5))
    plt.scatter(all_labels, all_preds, alpha=0.5)
    plt.plot([min(all_labels), max(all_labels)], [min(all_labels), max(all_labels)], color='red')
    plt.xlabel("True Values")
    plt.ylabel("Predicted Values")
    plt.title("True vs Predicted Values")
    plt.show()

# %%
datafile = pd.read_csv("tox24_challenge_train.csv")

# %%
smiles_list = datafile["SMILES"].to_list()
activity_values = datafile["activity"].to_list()

# %%
def smiles_to_fingerprint(smiles, radius=2, n_bits=1024):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None
    fp = AllChem.GetMorganFingerprintAsBitVect(mol, radius, nBits=n_bits)
    arr = np.zeros((1,), dtype=np.int8)
    DataStructs.ConvertToNumpyArray(fp, arr)
    return arr

# %%
fingerprints = np.array([smiles_to_fingerprint(s) for s in smiles_list if smiles_to_fingerprint(s) is not None])
# Out:
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# [03:05:05] DEPRECATION WARNING: please use MorganGenerator
# ...
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator
# [03:05:06] DEPRECATION WARNING: please use MorganGenerator

# %%
final = pd.concat([datafile,pd.DataFrame(fingerprints)],axis=1).drop("SMILES",axis=1)

# %%
final = final[final["activity"]>=0]

# %%
input_dim = 1024
hidden_dim1 = 500
hidden_dim2 = 200
hidden_dim3 = 50
hidden_dim4 = 10
dropout_rate = 0.2
epochs = 100


model = NNRegressor(input_dim, hidden_dim1, hidden_dim2, hidden_dim3, hidden_dim4, dropout_rate)
criterion = RMSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)


label_column = "activity"
train_df, test_df = train_test_split(final, test_size=0.3, random_state=42)

train_dataset = NNDataset(train_df, label_column)
test_dataset = NNDataset(test_df, label_column)

train_loader = DataLoader(train_dataset, batch_size=100, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=100, shuffle=False)

# %%
train_model(model, train_loader, optimizer, criterion, epochs)
# Out:
# Epoch [1/100], RMSE Loss: 48.8190
# Epoch [2/100], RMSE Loss: 36.6697
# Epoch [3/100], RMSE Loss: 29.4520
# Epoch [4/100], RMSE Loss: 25.7529
# Epoch [5/100], RMSE Loss: 24.3415
# Epoch [6/100], RMSE Loss: 22.2531
# Epoch [7/100], RMSE Loss: 19.8017
# Epoch [8/100], RMSE Loss: 18.5057
# Epoch [9/100], RMSE Loss: 19.5141
# Epoch [10/100], RMSE Loss: 19.2006
# Epoch [11/100], RMSE Loss: 19.0917
# Epoch [12/100], RMSE Loss: 17.8056
# Epoch [13/100], RMSE Loss: 17.7537
# Epoch [14/100], RMSE Loss: 18.5710
# Epoch [15/100], RMSE Loss: 16.9507
# Epoch [16/100], RMSE Loss: 18.4548
# Epoch [17/100], RMSE Loss: 16.9668
# Epoch [18/100], RMSE Loss: 18.1026
# Epoch [19/100], RMSE Loss: 19.2399
# Epoch [20/100], RMSE Loss: 18.4251
# Epoch [21/100], RMSE Loss: 17.5219
# Epoch [22/100], RMSE Loss: 18.4138
# Epoch [23/100], RMSE Loss: 17.6721
# Epoch [24/100], RMSE Loss: 16.8932
# Epoch [25/100], RMSE Loss: 16.7772
# Epoch [26/100], RMSE Loss: 16.8729
# Epoch [27/100], RMSE Loss: 17.5178
# Epoch [28/100], RMSE Loss: 16.8773
# Epoch [29/100], RMSE Loss: 17.1072
# Epoch [30/100], RMSE Loss: 18.3546
# Epoch [31/100], RMSE Loss: 17.2407
# Epoch [32/100], RMSE Loss: 15.1690
# Epoch [33/100], RMSE Loss: 17.6357
# Epoch [34/100], RMSE Loss: 16.7868
# Epoch [35/100], RMSE Loss: 16.9799
# Epoch [36/100], RMSE Loss: 16.3411
# Epoch [37/100], RMSE Loss: 17.2215
# Epoch [38/100], RMSE Loss: 16.5577
# Epoch [39/100], RMSE Loss: 17.4377
# Epoch [40/100], RMSE Loss: 17.7232
# Epoch [41/100], RMSE Loss: 16.2256
# Epoch [42/100], RMSE Loss: 17.4172
# Epoch [43/100], RMSE Loss: 16.9011
# Epoch [44/100], RMSE Loss: 16.0711
# Epoch [45/100], RMSE Loss: 16.9075
# Epoch [46/100], RMSE Loss: 17.4677
# Epoch [47/100], RMSE Loss: 16.0104
# Epoch [48/100], RMSE Loss: 15.1688
# Epoch [49/100], RMSE Loss: 15.7165
# Epoch [50/100], RMSE Loss: 19.0632
# Epoch [51/100], RMSE Loss: 18.7215
# Epoch [52/100], RMSE Loss: 16.5440
# Epoch [53/100], RMSE Loss: 16.6698
# Epoch [54/100], RMSE Loss: 16.3202
# Epoch [55/100], RMSE Loss: 16.3805
# Epoch [56/100], RMSE Loss: 15.7829
# Epoch [57/100], RMSE Loss: 16.6416
# Epoch [58/100], RMSE Loss: 15.6244
# Epoch [59/100], RMSE Loss: 16.9550
# Epoch [60/100], RMSE Loss: 14.7361
# Epoch [61/100], RMSE Loss: 14.8762
# Epoch [62/100], RMSE Loss: 16.1865
# Epoch [63/100], RMSE Loss: 16.8754
# Epoch [64/100], RMSE Loss: 16.0784
# Epoch [65/100], RMSE Loss: 16.7663
# Epoch [66/100], RMSE Loss: 16.1077
# Epoch [67/100], RMSE Loss: 16.5306
# Epoch [68/100], RMSE Loss: 15.3690
# Epoch [69/100], RMSE Loss: 17.6904
# Epoch [70/100], RMSE Loss: 16.3545
# Epoch [71/100], RMSE Loss: 16.4030
# Epoch [72/100], RMSE Loss: 16.2253
# Epoch [73/100], RMSE Loss: 16.5394
# Epoch [74/100], RMSE Loss: 15.4288
# Epoch [75/100], RMSE Loss: 15.6233
# Epoch [76/100], RMSE Loss: 15.0633
# Epoch [77/100], RMSE Loss: 16.3808
# Epoch [78/100], RMSE Loss: 15.7956
# Epoch [79/100], RMSE Loss: 16.3534
# Epoch [80/100], RMSE Loss: 14.9599
# Epoch [81/100], RMSE Loss: 15.9429
# Epoch [82/100], RMSE Loss: 16.1907
# Epoch [83/100], RMSE Loss: 15.4808
# Epoch [84/100], RMSE Loss: 15.6337
# Epoch [85/100], RMSE Loss: 16.6462
# Epoch [86/100], RMSE Loss: 16.2195
# Epoch [87/100], RMSE Loss: 15.1622
# Epoch [88/100], RMSE Loss: 16.1445
# Epoch [89/100], RMSE Loss: 16.4609
# Epoch [90/100], RMSE Loss: 15.4296
# Epoch [91/100], RMSE Loss: 15.3208
# Epoch [92/100], RMSE Loss: 15.9151
# Epoch [93/100], RMSE Loss: 15.0004
# Epoch [94/100], RMSE Loss: 15.5278
# Epoch [95/100], RMSE Loss: 14.7842
# Epoch [96/100], RMSE Loss: 15.3912
# Epoch [97/100], RMSE Loss: 16.1327
# Epoch [98/100], RMSE Loss: 15.6221
# Epoch [99/100], RMSE Loss: 14.4106
# Epoch [100/100], RMSE Loss: 15.9471

# %%
evaluate_model(model, test_loader, criterion)
# Out:
# Test RMSE Loss: 27.3469
# Test R²: 0.2932

# %%
#checkpoint

# %%
input_dim = 1024
hidden_dim1 = 1024
hidden_dim2 = 500
hidden_dim3 = 50
hidden_dim4 = 5
dropout_rate = 0.1
epochs = 100


model = NNRegressor(input_dim, hidden_dim1, hidden_dim2, hidden_dim3, hidden_dim4, dropout_rate)
criterion = RMSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)


label_column = "activity"
train_df, test_df = train_test_split(final, test_size=0.3, random_state=42)

train_dataset = NNDataset(train_df, label_column)
test_dataset = NNDataset(test_df, label_column)

train_loader = DataLoader(train_dataset, batch_size=50, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=50, shuffle=False)
